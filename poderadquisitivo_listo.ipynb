# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.makedirs("datos_poder_adquisitivo", exist_ok=True)

# %%
ruta = "datos_poder_adquisitivo/anex-IPC-indices-may2026 (1).xlsx"

# %%
df = pd.read_excel(ruta, header=8)

# %%
df.head()
# Out:
#        Mes   2003   2004   2005   2006   2007   2008   2009   2010   2011  \
# 0    Enero  50.42  53.54  56.45  59.02  61.80  65.51  70.21  71.69  74.12
# 1  Febrero  50.98  54.18  57.02  59.41  62.53  66.50  70.80  72.28  74.57
# 2    Marzo  51.51  54.71  57.46  59.83  63.29  67.04  71.15  72.46  74.77
# 3    Abril  52.10  54.96  57.72  60.09  63.85  67.51  71.38  72.79  74.86
# 4     Mayo  52.36  55.17  57.95  60.29  64.05  68.14  71.39  72.87  75.07
#
#    ...   2017   2018    2019    2020    2021    2022    2023    2024    2025  \
# 0  ...  94.07  97.53  100.60  104.24  105.91  113.26  128.27  138.98  146.24
# 1  ...  95.01  98.22  101.18  104.94  106.58  115.11  130.40  140.49  147.90
# 2  ...  95.46  98.45  101.62  105.53  107.12  116.26  131.77  141.48  148.68
# 3  ...  95.91  98.91  102.12  105.70  107.76  117.71  132.80  142.32  149.66
# 4  ...  96.12  99.16  102.44  105.36  108.84  118.70  133.38  142.92  150.14
#
#      2026
# 0  154.07
# 1  155.73
# 2  156.94
# 3  158.17
# 4  158.91
#
# [5 rows x 25 columns]

# %%
df_ipc_largo = df.melt(id_vars="Mes", var_name="Año", value_name="IPC")
df_ipc_largo["Año"] = pd.to_numeric(df_ipc_largo["Año"], errors="coerce")
df_ipc_largo = df_ipc_largo.dropna(subset=["Año"])
df_ipc_largo["Año"] = df_ipc_largo["Año"].astype(int)

condicion1 = df_ipc_largo["Año"] >= 2016
condicion2 = df_ipc_largo["Año"] <= 2025
df_ipc_filtrado = df_ipc_largo[condicion1 & condicion2]
df_ipc_filtrado = df_ipc_filtrado.dropna(subset=["IPC"])
df_ipc_filtrado
# Out:
#             Mes   Año     IPC
# 221       Enero  2016   89.19
# 222     Febrero  2016   90.33
# 223       Marzo  2016   91.18
# 224       Abril  2016   91.63
# 225        Mayo  2016   92.10
# ..          ...   ...     ...
# 381      Agosto  2025  150.99
# 382  Septiembre  2025  151.48
# 383     Octubre  2025  151.76
# 384   Noviembre  2025  151.87
# 385   Diciembre  2025  152.27
#
# [120 rows x 3 columns]

# %%
print(df.shape) 
pd.set_option("display.max_rows", None)
df_ipc_filtrado
# Out:
# (17, 25)
#             Mes   Año     IPC
# 221       Enero  2016   89.19
# 222     Febrero  2016   90.33
# 223       Marzo  2016   91.18
# 224       Abril  2016   91.63
# 225        Mayo  2016   92.10
# 226       Junio  2016   92.54
# 227       Julio  2016   93.02
# 228      Agosto  2016   92.73
# 229  Septiembre  2016   92.68
# 230     Octubre  2016   92.62
# 231   Noviembre  2016   92.73
# 232   Diciembre  2016   93.11
# 238       Enero  2017   94.07
# 239     Febrero  2017   95.01
# 240       Marzo  2017   95.46
# 241       Abril  2017   95.91
# 242        Mayo  2017   96.12
# 243       Junio  2017   96.23
# 244       Julio  2017   96.18
# 245      Agosto  2017   96.32
# 246  Septiembre  2017   96.36
# 247     Octubre  2017   96.37
# 248   Noviembre  2017   96.55
# 249   Diciembre  2017   96.92
# 255       Enero  2018   97.53
# 256     Febrero  2018   98.22
# 257       Marzo  2018   98.45
# 258       Abril  2018   98.91
# 259        Mayo  2018   99.16
# 260       Junio  2018   99.31
# 261       Julio  2018   99.18
# 262      Agosto  2018   99.30
# 263  Septiembre  2018   99.47
# 264     Octubre  2018   99.59
# 265   Noviembre  2018   99.70
# 266   Diciembre  2018  100.00
# 272       Enero  2019  100.60
# 273     Febrero  2019  101.18
# 274       Marzo  2019  101.62
# 275       Abril  2019  102.12
# 276        Mayo  2019  102.44
# 277       Junio  2019  102.71
# 278       Julio  2019  102.94
# 279      Agosto  2019  103.03
# 280  Septiembre  2019  103.26
# 281     Octubre  2019  103.43
# 282   Noviembre  2019  103.54
# 283   Diciembre  2019  103.80
# 289       Enero  2020  104.24
# 290     Febrero  2020  104.94
# 291       Marzo  2020  105.53
# 292       Abril  2020  105.70
# 293        Mayo  2020  105.36
# 294       Junio  2020  104.97
# 295       Julio  2020  104.97
# 296      Agosto  2020  104.96
# 297  Septiembre  2020  105.29
# 298     Octubre  2020  105.23
# 299   Noviembre  2020  105.08
# 300   Diciembre  2020  105.48
# 306       Enero  2021  105.91
# 307     Febrero  2021  106.58
# 308       Marzo  2021  107.12
# 309       Abril  2021  107.76
# 310        Mayo  2021  108.84
# 311       Junio  2021  108.78
# 312       Julio  2021  109.14
# 313      Agosto  2021  109.62
# 314  Septiembre  2021  110.04
# 315     Octubre  2021  110.06
# 316   Noviembre  2021  110.60
# 317   Diciembre  2021  111.41
# 323       Enero  2022  113.26
# 324     Febrero  2022  115.11
# 325       Marzo  2022  116.26
# 326       Abril  2022  117.71
# 327        Mayo  2022  118.70
# 328       Junio  2022  119.31
# 329       Julio  2022  120.27
# 330      Agosto  2022  121.50
# 331  Septiembre  2022  122.63
# 332     Octubre  2022  123.51
# 333   Noviembre  2022  124.46
# 334   Diciembre  2022  126.03
# 340       Enero  2023  128.27
# 341     Febrero  2023  130.40
# 342       Marzo  2023  131.77
# 343       Abril  2023  132.80
# 344        Mayo  2023  133.38
# 345       Junio  2023  133.78
# 346       Julio  2023  134.45
# 347      Agosto  2023  135.39
# 348  Septiembre  2023  136.11
# 349     Octubre  2023  136.45
# 350   Noviembre  2023  137.09
# 351   Diciembre  2023  137.72
# 357       Enero  2024  138.98
# 358     Febrero  2024  140.49
# 359       Marzo  2024  141.48
# 360       Abril  2024  142.32
# 361        Mayo  2024  142.92
# 362       Junio  2024  143.38
# 363       Julio  2024  143.67
# 364      Agosto  2024  143.67
# 365  Septiembre  2024  144.02
# 366     Octubre  2024  143.83
# 367   Noviembre  2024  144.22
# 368   Diciembre  2024  144.88
# 374       Enero  2025  146.24
# 375     Febrero  2025  147.90
# 376       Marzo  2025  148.68
# 377       Abril  2025  149.66
# 378        Mayo  2025  150.14
# 379       Junio  2025  150.30
# 380       Julio  2025  150.71
# 381      Agosto  2025  150.99
# 382  Septiembre  2025  151.48
# 383     Octubre  2025  151.76
# 384   Noviembre  2025  151.87
# 385   Diciembre  2025  152.27

# %%
ruta_smmlv = "datos_poder_adquisitivo/mercado laborarl.xlsx"
df_smmlv = pd.read_excel(ruta_smmlv)
df_smmlv.head(15)
# Out:
#   Metadatos del Grupo Serie: Mercado laboral (Salario mínimo legal en Colombia)\n   \
# 0                                              Serie
# 1                      Auxilio de transporte mensual
# 2                             Salario mínimo mensual
# 3               Salario mínimo mensual, sector rural
# 4         Salario mínimo mensual, sector urbano alto
# 5   \nDescargado del sistema del Banco de la Repú...
#
#      Unnamed: 1 Unnamed: 2                                         Unnamed: 3  \
# 0  Periodicidad     Moneda                                             Fuente
# 1         Anual        COP  Ministerio del Trabajo,\nPresidencia de la Rep...
# 2         Anual        COP  Ministerio del Trabajo,\nPresidencia de la Rep...
# 3         Anual        COP  Ministerio del Trabajo,\nPresidencia de la Rep...
# 4         Anual        COP  Ministerio del Trabajo,\nPresidencia de la Rep...
# 5           NaN        NaN                                                NaN
#
#             Unnamed: 4           Unnamed: 5  \
# 0   Disponible \ndesde   Disponible \nhasta
# 1  1979-12-31 00:00:00  2026-12-31 00:00:00
# 2  1984-12-31 00:00:00  2026-12-31 00:00:00
# 3  1950-12-31 00:00:00  1983-12-31 00:00:00
# 4  1950-12-31 00:00:00  1983-12-31 00:00:00
# 5                  NaN                  NaN
#
#                                           Unnamed: 6
# 0                                              Notas
# 1                                                NaN
# 2  1. Desde el 1 de julio de 1984 se unificó el s...
# 3  1. Los decretos anteriores al año 1969 fijaban...
# 4  1. Los decretos anteriores al año 1969 fijaban...
# 5                                                NaN

# %%
xls = pd.ExcelFile(ruta_smmlv)
print(xls.sheet_names)
# Out:
# ['Metadatos', 'Series de datos']

# %%
df_smmlv = pd.read_excel(ruta_smmlv, sheet_name="Series de datos", header=2)
df_smmlv.head(15)
# Out:
#              Unnamed: 0 Auxilio de transporte mensual Salario mínimo mensual  \
# 0   1950-12-31 00:00:00                             .                      .
# 1   1951-12-31 00:00:00                             .                      .
# 2   1952-12-31 00:00:00                             .                      .
# 3   1953-12-31 00:00:00                             .                      .
# 4   1954-12-31 00:00:00                             .                      .
# 5   1955-12-31 00:00:00                             .                      .
# 6   1956-12-31 00:00:00                             .                      .
# 7   1957-12-31 00:00:00                             .                      .
# 8   1958-12-31 00:00:00                             .                      .
# 9   1959-12-31 00:00:00                             .                      .
# 10  1960-12-31 00:00:00                             .                      .
# 11  1961-12-31 00:00:00                             .                      .
# 12  1962-12-31 00:00:00                             .                      .
# 13  1963-12-31 00:00:00                             .                      .
# 14  1964-12-31 00:00:00                             .                      .
#
#    Salario mínimo mensual, sector rural  \
# 0                                    60
# 1                                    60
# 2                                    60
# 3                                    60
# 4                                    60
# 5                                    60
# 6                                    96
# 7                                   110
# 8                                   110
# 9                                   110
# 10                                  132
# 11                                  132
# 12                                  210
# 13                                  270
# 14                                  270
#
#    Salario mínimo mensual, sector urbano alto
# 0                                          60
# 1                                          60
# 2                                          60
# 3                                          60
# 4                                          60
# 5                                          60
# 6                                         135
# 7                                       155.4
# 8                                       155.4
# 9                                       155.4
# 10                                        198
# 11                                        198
# 12                                        300
# 13                                        420
# 14                                        420

# %%
print(df_smmlv.columns)
# Out:
# Index(['Unnamed: 0', 'Auxilio de transporte mensual', 'Salario mínimo mensual',
#        'Salario mínimo mensual, sector rural',
#        'Salario mínimo mensual, sector urbano alto'],
#       dtype='str')

# %%
df_smmlv = df_smmlv.rename(columns={df_smmlv.columns[0]: "Fecha"})
df_smmlv["Fecha"] = pd.to_datetime(df_smmlv["Fecha"], errors="coerce")
df_smmlv = df_smmlv.dropna(subset=["Fecha"])
df_smmlv["Año"] = df_smmlv["Fecha"].dt.year

df_smmlv_filtrado = df_smmlv[(df_smmlv["Año"] >= 2016) & (df_smmlv["Año"] <= 2025)]
df_smmlv_filtrado
# Out:
#         Fecha Auxilio de transporte mensual Salario mínimo mensual  \
# 66 2016-12-31                         77700                 689455
# 67 2017-12-31                         83140                 737717
# 68 2018-12-31                         88211                 781242
# 69 2019-12-31                         97032                 828116
# 70 2020-12-31                        102854                 877803
# 71 2021-12-31                        106454                 908526
# 72 2022-12-31                        117172                1000000
# 73 2023-12-31                        140606                1160000
# 74 2024-12-31                        162000                1300000
# 75 2025-12-31                        200000                1423500
#
#    Salario mínimo mensual, sector rural  \
# 66                                    .
# 67                                    .
# 68                                    .
# 69                                    .
# 70                                    .
# 71                                    .
# 72                                    .
# 73                                    .
# 74                                    .
# 75                                    .
#
#    Salario mínimo mensual, sector urbano alto   Año
# 66                                          .  2016
# 67                                          .  2017
# 68                                          .  2018
# 69                                          .  2019
# 70                                          .  2020
# 71                                          .  2021
# 72                                          .  2022
# 73                                          .  2023
# 74                                          .  2024
# 75                                          .  2025

# %%
df_smmlv_filtrado = df_smmlv_filtrado.iloc[:, [0, 5, 2, 1]]
df_smmlv_filtrado.columns = ["Fecha", "Año", "Salario minimo mensual", "Auxilio de transporte mensual"]
df_smmlv_filtrado
# Out:
#         Fecha   Año Salario minimo mensual Auxilio de transporte mensual
# 66 2016-12-31  2016                 689455                         77700
# 67 2017-12-31  2017                 737717                         83140
# 68 2018-12-31  2018                 781242                         88211
# 69 2019-12-31  2019                 828116                         97032
# 70 2020-12-31  2020                 877803                        102854
# 71 2021-12-31  2021                 908526                        106454
# 72 2022-12-31  2022                1000000                        117172
# 73 2023-12-31  2023                1160000                        140606
# 74 2024-12-31  2024                1300000                        162000
# 75 2025-12-31  2025                1423500                        200000

# %%
ruta_pobreza = "datos_poder_adquisitivo/anex-PM-TotalNacional-2025.xlsx"
xls_pobreza = pd.ExcelFile(ruta_pobreza)
print(xls_pobreza.sheet_names)
# Out:
# ['Índice', 'Ficha metodológica', 'Población', 'Pobreza Monetaria Act.Met.', 'IC_IP Act.Met.', 'Pobreza Extrema Act.Met.', 'IC_IPE Act.Met.', 'Gini', 'Ingpc Act.Met.', 'LP_LI Act.Met.', 'Brecha Act.Met.', 'IC_Brecha Act.Met.', 'Severidad Act.Met.', 'IC_Severidad Act.Met.', 'IP_Perfil Jefe Act.Met.', 'IC._IP_Perfil Jefe Act.Met.', 'IPE_Perfil Jefe Act.Met.', 'IC._IPE_Perfil Jefe Act.Met.', 'IP_Perfil_Hogar Act.Met.', 'IC._IP_Perfil Hogar Act.Met.', 'IPE_Perfil_Hogar Act.Met.', 'IC._IPE_Perfil Hogar Act.Met.', 'IP_Sexo Act.Met.', 'IPE_Sexo Act.Met.']

# %%
df_pobreza_raw = pd.read_excel(ruta_pobreza, sheet_name="LP_LI Act.Met.", header=None)
df_pobreza_raw.head(20)
# Out:
#                                                    0         1         2   \
# 0                                                 NaN       NaN       NaN
# 1                                                 NaN       NaN       NaN
# 2                 Líneas de pobreza y pobreza extrema       NaN       NaN
# 3   Líneas de Pobreza Monetaria (valores mensuales...       NaN       NaN
# 4                                                 NaN       NaN       NaN
# 5                                                 NaN       NaN       NaN
# 6                                                 NaN       NaN       NaN
# 7                                                 NaN       NaN       NaN
# 8                                                 NaN       NaN       NaN
# 9                          Cifras en pesos corrientes       NaN       NaN
# 10                                   Grandes dominios       NaN       NaN
# 11                                                NaN    2012.0    2013.0
# 12                                            Armenia  290383.0  292430.0
# 13                                  Barranquilla A.M.  242985.0  245466.0
# 14                                             Bogotá  338793.0  346497.0
# 15                                   Bucaramanga A.M.  332093.0  340237.0
# 16                                          Cali A.M.  258558.0  262965.0
# 17                                          Cartagena  266997.0  270446.0
# 18                                        Cúcuta A.M.  248737.0  247455.0
# 19                                          Florencia  272300.0  274681.0
#
#           3         4         5         6         7         8         9   \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 10       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 11    2014.0    2015.0    2016.0    2017.0    2018.0    2019.0    2020.0
# 12  302631.0  321837.0  353148.0  365887.0  374819.0  390075.0  400035.0
# 13  254998.0  274087.0  297445.0  305591.0  314685.0  327162.0  338665.0
# 14  357460.0  377901.0  407889.0  423187.0  434630.0  448757.0  455038.0
# 15  355116.0  376526.0  405930.0  420277.0  432642.0  447152.0  453609.0
# 16  272880.0  288444.0  313432.0  323143.0  331679.0  346274.0  356960.0
# 17  281127.0  301403.0  325122.0  331079.0  341693.0  354984.0  360250.0
# 18  252800.0  266986.0  291623.0  294781.0  302179.0  315669.0  326078.0
# 19  284217.0  302194.0  331026.0  340510.0  345495.0  358625.0  365718.0
#
#           10        11        12        13        14
# 0        NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN       NaN
# 4        NaN       NaN       NaN       NaN       NaN
# 5        NaN       NaN       NaN       NaN       NaN
# 6        NaN       NaN       NaN       NaN       NaN
# 7        NaN       NaN       NaN       NaN       NaN
# 8        NaN       NaN       NaN       NaN       NaN
# 9        NaN       NaN       NaN       NaN       NaN
# 10       NaN       NaN       NaN       NaN       NaN
# 11    2021.0    2022.0    2023.0    2024.0    2025.0
# 12  429892.0  486223.0  533420.0  563159.0  588462.0
# 13  359394.0  409913.0  451714.0  474571.0  498721.0
# 14  477217.0  536108.0  592369.0  628604.0  660533.0
# 15  481836.0  547356.0  599865.0  638918.0  670169.0
# 16  376796.0  427199.0  467350.0  492236.0  511638.0
# 17  376426.0  427667.0  473838.0  501919.0  524805.0
# 18  349507.0  409770.0  452516.0  477637.0  498198.0
# 19  393613.0  441514.0  484165.0  514847.0  540401.0

# %%
df_pobreza_raw.iloc[30:40]
# Out:
#                                    0         1         2         3         4   \
# 30                        Santa Marta  254349.0  257564.0  267153.0  283914.0
# 31                          Sincelejo  227650.0  229836.0  237519.0  256860.0
# 32                              Tunja  331759.0  337401.0  350449.0  368840.0
# 33                         Valledupar  257324.0  259312.0  268756.0  286351.0
# 34                      Villavicencio  294528.0  302314.0  312088.0  328985.0
# 35                           Nacional  246815.0  251126.0  260006.0  275583.0
# 36                          Cabeceras  274294.0  279060.0  288699.0  305830.0
# 37  Centros poblados y rural disperso  161889.0  164382.0  170518.0  180869.0
# 38                 13 ciudades y A.M.  300688.0  306280.0  316866.0  335726.0
# 39                    Otras cabeceras  235603.0  239408.0  247957.0  262915.0
#
#           5         6         7         8         9         10        11  \
# 30  304576.0  311308.0  317103.0  330253.0  344376.0  368154.0  421746.0
# 31  281377.0  284985.0  293364.0  306919.0  316883.0  329776.0  381707.0
# 32  397623.0  405830.0  415623.0  431859.0  441722.0  459403.0  528245.0
# 33  306571.0  311050.0  315194.0  326904.0  332039.0  353150.0  404148.0
# 34  351903.0  354622.0  360987.0  371457.0  373064.0  397579.0  447311.0
# 35  297933.0  306653.0  314294.0  325145.0  329080.0  351480.0  396864.0
# 36  330442.0  340324.0  348919.0  360547.0  368595.0  389295.0  440047.0
# 37  195712.0  200339.0  204313.0  210967.0  199825.0  226520.0  253150.0
# 38  363051.0  375336.0  385697.0  399843.0  407956.0  430175.0  485632.0
# 39  283997.0  290863.0  297377.0  305800.0  314093.0  333139.0  377836.0
#
#           12        13        14
# 30  464466.0  478195.0  490202.0
# 31  429856.0  459238.0  475951.0
# 32  575440.0  603972.0  620017.0
# 33  448300.0  468612.0  488369.0
# 34  482855.0  505721.0  531554.0
# 35  435375.0  460198.0  482041.0
# 36  483521.0  510161.0  532906.0
# 37  274160.0  291998.0  310029.0
# 38  534507.0  566228.0  593128.0
# 39  414314.0  434323.0  451673.0

# %%
df_pobreza = pd.read_excel(ruta_pobreza, sheet_name="LP_LI Act.Met.", header=11)
df_pobreza.head(3)
# Out:
#           Unnamed: 0      2012      2013      2014      2015      2016  \
# 0            Armenia  290383.0  292430.0  302631.0  321837.0  353148.0
# 1  Barranquilla A.M.  242985.0  245466.0  254998.0  274087.0  297445.0
# 2             Bogotá  338793.0  346497.0  357460.0  377901.0  407889.0
#
#        2017      2018      2019      2020      2021      2022      2023  \
# 0  365887.0  374819.0  390075.0  400035.0  429892.0  486223.0  533420.0
# 1  305591.0  314685.0  327162.0  338665.0  359394.0  409913.0  451714.0
# 2  423187.0  434630.0  448757.0  455038.0  477217.0  536108.0  592369.0
#
#        2024      2025
# 0  563159.0  588462.0
# 1  474571.0  498721.0
# 2  628604.0  660533.0

# %%
fila_nacional = df_pobreza[df_pobreza["Unnamed: 0"] == "Nacional"]
fila_nacional
# Out:
#    Unnamed: 0      2012      2013      2014      2015      2016      2017  \
# 23   Nacional  246815.0  251126.0  260006.0  275583.0  297933.0  306653.0
# 62   Nacional  102755.0  102395.0  106764.0  115724.0  129863.0  129618.0
#
#         2018      2019      2020      2021      2022      2023      2024  \
# 23  314294.0  325145.0  329080.0  351480.0  396864.0  435375.0  460198.0
# 62  130297.0  136638.0  144290.0  160302.0  198698.0  218846.0  227220.0
#
#         2025
# 23  482041.0
# 62  236580.0

# %%
años = list(range(2016, 2026))
fila_nacional_filtrada = fila_nacional[años]
fila_nacional_filtrada
# Out:
#         2016      2017      2018      2019      2020      2021      2022  \
# 23  297933.0  306653.0  314294.0  325145.0  329080.0  351480.0  396864.0
# 62  129863.0  129618.0  130297.0  136638.0  144290.0  160302.0  198698.0
#
#         2023      2024      2025
# 23  435375.0  460198.0  482041.0
# 62  218846.0  227220.0  236580.0

# %%
linea_pobreza = fila_nacional_filtrada.iloc[0]
linea_pobreza_extrema = fila_nacional_filtrada.iloc[1]

df_pobreza_final = pd.DataFrame({
    "Año": años,
    "Linea_pobreza": linea_pobreza.values,
    "Linea_pobreza_extrema": linea_pobreza_extrema.values
})
df_pobreza_final
# Out:
#     Año  Linea_pobreza  Linea_pobreza_extrema
# 0  2016       297933.0               129863.0
# 1  2017       306653.0               129618.0
# 2  2018       314294.0               130297.0
# 3  2019       325145.0               136638.0
# 4  2020       329080.0               144290.0
# 5  2021       351480.0               160302.0
# 6  2022       396864.0               198698.0
# 7  2023       435375.0               218846.0
# 8  2024       460198.0               227220.0
# 9  2025       482041.0               236580.0

# %%
ruta_costo_matricula_privada = "datos_poder_adquisitivo/costo_matricula_universitaria.xlsx"

# %%
df_matricula = pd.read_excel(ruta_costo_matricula_privada)

# %%
df_matricula.head(2)
# Out:
#                                      Categoria  Valor_minimo_COP  \
# 0                  Medicina (a nivel nacional)        11980940.0
# 1  Resto de las carreras (excluyendo Medicina)         3000000.0
#
#    Valor_maximo_COP  Valor_promedio_COP
# 0        38220000.0          25000000.0
# 1        11700000.0           8500000.0

# %%
ruta_costo_matricula_publica = "datos_poder_adquisitivo/costo_matricula_publica.xlsx"

# %%
df_matriculapublica = pd.read_excel(ruta_costo_matricula_publica)

# %%
df_matriculapublica.head(2)
# Out:
#                                            Categoria  Valor_minimo_COP  \
# 0  Politica de Gratuidad (cubre ~97% de estudiant...               0.0
# 1  Fuera de gratuidad (estrato 4-6, mayoria de ca...          100000.0
#
#    Valor_maximo_COP  Valor_promedio_COP
# 0               0.0                 0.0
# 1         3500000.0           1200000.0

# %% [markdown]
# ## Tabla Maestra
#
# Unimos los seis indicadores en una sola tabla: año a año, de 2016 a 2025.
#
# Para el IPC usamos el **último mes disponible de cada año**:
# - 2016–2025 → Diciembre
#
# Este valor del IPC representa el nivel de precios al cierre de cada año, que es el que el Gobierno usa como referencia para fijar el salario del año siguiente. Así la comparación es consistente.

# %%
# Mapa de meses en número (para ordenar y filtrar)
orden_mes = {
    "Enero": 1, "Febrero": 2, "Marzo": 3, "Abril": 4,
    "Mayo": 5, "Junio": 6, "Julio": 7, "Agosto": 8,
    "Septiembre": 9, "Octubre": 10, "Noviembre": 11, "Diciembre": 12
}
df_ipc_filtrado = df_ipc_filtrado.copy()
df_ipc_filtrado["Mes_num"] = df_ipc_filtrado["Mes"].map(orden_mes)

# Solo hasta 2025 — 2026 tiene IPC parcial (mayo), no comparable
df_ipc_filtrado = df_ipc_filtrado[df_ipc_filtrado["Año"] <= 2025]

# Último mes disponible por año
ipc_ultimo_mes = (
    df_ipc_filtrado
    .sort_values(["Año", "Mes_num"])
    .groupby("Año", as_index=False)
    .last()[["Año", "IPC", "Mes"]]
    .rename(columns={"Mes": "Mes_IPC"})
)
ipc_ultimo_mes
# Out:
#     Año     IPC    Mes_IPC
# 0  2016   93.11  Diciembre
# 1  2017   96.92  Diciembre
# 2  2018  100.00  Diciembre
# 3  2019  103.80  Diciembre
# 4  2020  105.48  Diciembre
# 5  2021  111.41  Diciembre
# 6  2022  126.03  Diciembre
# 7  2023  137.72  Diciembre
# 8  2024  144.88  Diciembre
# 9  2025  152.27  Diciembre

# %%
# Preparar df_smmlv_filtrado con columnas limpias y tipo numérico
df_salario = df_smmlv_filtrado[["Año", "Salario minimo mensual", "Auxilio de transporte mensual"]]
df_salario["Año"] = df_salario["Año"].astype(int)
df_salario["Salario minimo mensual"] = pd.to_numeric(df_salario["Salario minimo mensual"], errors="coerce")
df_salario["Auxilio de transporte mensual"] = pd.to_numeric(df_salario["Auxilio de transporte mensual"], errors="coerce")

# Solo hasta 2025 — consistente con el corte del IPC
df_salario = df_salario[df_salario["Año"] <= 2025]

# Preparar línea de pobreza
df_pob = df_pobreza_final.copy()
df_pob["Año"] = df_pob["Año"].astype(int)

# Unir todo
df_maestro = (
    df_salario
    .merge(ipc_ultimo_mes, on="Año", how="left")
    .merge(df_pob, on="Año", how="left")
)

# Renombrar columnas para claridad
df_maestro.columns = [
    "Año", "Salario_nominal", "Auxilio_transporte",
    "IPC", "Mes_IPC",
    "Linea_pobreza", "Linea_pobreza_extrema"
]

df_maestro
# Out:
#     Año  Salario_nominal  Auxilio_transporte     IPC    Mes_IPC  \
# 0  2016           689455               77700   93.11  Diciembre
# 1  2017           737717               83140   96.92  Diciembre
# 2  2018           781242               88211  100.00  Diciembre
# 3  2019           828116               97032  103.80  Diciembre
# 4  2020           877803              102854  105.48  Diciembre
# 5  2021           908526              106454  111.41  Diciembre
# 6  2022          1000000              117172  126.03  Diciembre
# 7  2023          1160000              140606  137.72  Diciembre
# 8  2024          1300000              162000  144.88  Diciembre
# 9  2025          1423500              200000  152.27  Diciembre
#
#    Linea_pobreza  Linea_pobreza_extrema
# 0       297933.0               129863.0
# 1       306653.0               129618.0
# 2       314294.0               130297.0
# 3       325145.0               136638.0
# 4       329080.0               144290.0
# 5       351480.0               160302.0
# 6       396864.0               198698.0
# 7       435375.0               218846.0
# 8       460198.0               227220.0
# 9       482041.0               236580.0

# %% [markdown]
#  Salario Real
#
# **¿Qué es deflactar?**
# El salario nominal es lo que dice el decreto — pesos del año en curso. El salario real descuenta la inflación para hacer los valores comparables entre años.
#
# **Fórmula:**
# ```
# Salario_real = Salario_nominal ÷ (IPC ÷ 100)
# ```
#
# Usamos IPC base diciembre 2018 = 100. Un salario real de 800.000 en 2016 y en 2025 significa que en ambos años se puede comprar la misma canasta.
#
# También calculamos:
# - **Variación nominal (%)** — cuánto subió el salario en pesos corrientes
# - **Variación real (%)** — cuánto subió el poder de compra real

# %%
# ── CAPA 1: Salario real ──────────────────────────────────────────────────────
df_maestro["Salario_real"] = df_maestro["Salario_nominal"] / (df_maestro["IPC"] / 100)
df_maestro["Auxilio_real"] = df_maestro["Auxilio_transporte"] / (df_maestro["IPC"] / 100)

# Variaciones interanuales (%)
df_maestro["Var_nominal_pct"] = df_maestro["Salario_nominal"].pct_change() * 100
df_maestro["Var_real_pct"]    = df_maestro["Salario_real"].pct_change() * 100

cols_capa1 = ["Año", "Salario_nominal", "IPC", "Mes_IPC", "Salario_real",
              "Var_nominal_pct", "Var_real_pct"]

df_maestro[cols_capa1].round(2).rename(
    columns={"Salario_real": "Salario real (precios constantes)"}
)
# Out:
#     Año  Salario_nominal     IPC    Mes_IPC  \
# 0  2016           689455   93.11  Diciembre
# 1  2017           737717   96.92  Diciembre
# 2  2018           781242  100.00  Diciembre
# 3  2019           828116  103.80  Diciembre
# 4  2020           877803  105.48  Diciembre
# 5  2021           908526  111.41  Diciembre
# 6  2022          1000000  126.03  Diciembre
# 7  2023          1160000  137.72  Diciembre
# 8  2024          1300000  144.88  Diciembre
# 9  2025          1423500  152.27  Diciembre
#
#    Salario real (precios constantes)  Var_nominal_pct  Var_real_pct
# 0                          740473.63              NaN           NaN
# 1                          761160.75             7.00          2.79
# 2                          781242.00             5.90          2.64
# 3                          797799.61             6.00          2.12
# 4                          832198.52             6.00          4.31
# 5                          815479.76             3.50         -2.01
# 6                          793461.87            10.07         -2.70
# 7                          842288.70            16.00          6.15
# 8                          897294.31            12.07          6.53
# 9                          934852.56             9.50          4.19

# %%
# Resumen 2016 vs 2025
sal_2016 = df_maestro.loc[df_maestro["Año"] == 2016, "Salario_real"].values[0]
sal_2025 = df_maestro.loc[df_maestro["Año"] == 2025, "Salario_real"].values[0]
cambio_real = ((sal_2025 - sal_2016) / sal_2016) * 100

print(f"Salario real 2016: ${sal_2016:,.0f} (precios constantes)")
print(f"Salario real 2025: ${sal_2025:,.0f} (precios constantes)")
print(f"Cambio acumulado 2016-2025: {cambio_real:+.1f}%")
# Out:
# Salario real 2016: $740,474 (precios constantes)
# Salario real 2025: $934,853 (precios constantes)
# Cambio acumulado 2016-2025: +26.3%

# %% [markdown]
# ## Capa 2 — ¿Vivir o Sobrevivir?
#
# Aquí comparamos lo que la persona **realmente recibe** (salario + auxilio de transporte) contra la **línea de pobreza** oficial del DANE.
#
# - Si `(Salario + Auxilio) > Línea de pobreza` → la persona no es pobre en términos monetarios
# - El **excedente** es lo que le sobra después de cubrir lo básico
#
# **Nota:** La línea de pobreza está en pesos corrientes de cada año, igual que el salario nominal. Se comparan en términos nominales — no hay que deflactar aquí porque ambas variables ya están en pesos del mismo año.
#
# El análisis cubre 2016–2025, con la línea de pobreza oficial del DANE disponible para todos esos años. No se incluye 2026 porque el IPC de ese año es parcial (solo hasta mayo).

# %%
# Calcular Excedente: Ingreso_total - Línea de pobreza
df_maestro["Ingreso_total"] = df_maestro["Salario_nominal"] + df_maestro["Auxilio_transporte"]
df_maestro["Excedente"] = df_maestro["Ingreso_total"] - df_maestro["Linea_pobreza"]

cols_capa2 = ["Año", "Salario_nominal", "Auxilio_transporte", "Ingreso_total",
              "Linea_pobreza", "Excedente"]
df_maestro[cols_capa2].round(0)
# Out:
#     Año  Salario_nominal  Auxilio_transporte  Ingreso_total  Linea_pobreza  \
# 0  2016           689455               77700         767155       297933.0
# 1  2017           737717               83140         820857       306653.0
# 2  2018           781242               88211         869453       314294.0
# 3  2019           828116               97032         925148       325145.0
# 4  2020           877803              102854         980657       329080.0
# 5  2021           908526              106454        1014980       351480.0
# 6  2022          1000000              117172        1117172       396864.0
# 7  2023          1160000              140606        1300606       435375.0
# 8  2024          1300000              162000        1462000       460198.0
# 9  2025          1423500              200000        1623500       482041.0
#
#    Excedente
# 0   469222.0
# 1   514204.0
# 2   555159.0
# 3   600003.0
# 4   651577.0
# 5   663500.0
# 6   720308.0
# 7   865231.0
# 8  1001802.0
# 9  1141459.0

# %%
# Cuántos años el ingreso estuvo por encima / por debajo de la línea de pobreza
encima = (df_maestro["Excedente"] > 0).sum()
debajo = (df_maestro["Excedente"] <= 0).sum()
print(f"Años con excedente positivo (sobre línea de pobreza): {encima}")
print(f"Años con excedente negativo (bajo línea de pobreza):  {debajo}")
print()
for _, row in df_maestro[["Año", "Excedente"]].iterrows():
    signo = "✅" if row["Excedente"] > 0 else "🔴"
    print(f"{signo} {int(row['Año'])}: ${row['Excedente']:,.0f}")
# Out:
# Años con excedente positivo (sobre línea de pobreza): 10
# Años con excedente negativo (bajo línea de pobreza):  0
#
# ✅ 2016: $469,222
# ✅ 2017: $514,204
# ✅ 2018: $555,159
# ✅ 2019: $600,003
# ✅ 2020: $651,577
# ✅ 2021: $663,500
# ✅ 2022: $720,308
# ✅ 2023: $865,231
# ✅ 2024: $1,001,802
# ✅ 2025: $1,141,459

# %% [markdown]
# ## ¿Alcanza para Estudiar?
#
# Tomamos el excedente mensual de cada año, lo multiplicamos por 6 (un semestre) y lo comparamos contra los costos de matrícula.
#
# **Referencias de costo:**
# - **Universidad privada — carreras generales:** promedio $8.500.000/semestre
# - **Universidad privada — Medicina:** promedio $25.000.000/semestre
# - **Universidad pública — Gratuidad (estratos 1-3):** $0/semestre (~97% de estudiantes)
# - **Universidad pública — Fuera de gratuidad (estratos 4-6):** promedio $1.200.000/semestre
#
# El excedente semestral no equivale a "ahorró todo eso" — una persona que gana el mínimo tiene otros gastos (arriendo, alimentación de toda la familia, servicios). El ejercicio muestra el **límite teórico** de lo que podría destinar a educación si cubriera todo lo básico justo con la línea de pobreza.

# %%
# ── CAPA 3: Comparación con matrícula ────────────────────────────────────────

# Costos de matrícula (fijos, datos 2024-2026)
matricula_privada_general  = 8_500_000
matricula_privada_medicina = 25_000_000
matricula_publica_gratuita = 0
matricula_publica_fuera    = 1_200_000

df_maestro["Excedente_semestral"] = df_maestro["Excedente"] * 6

df_maestro["Alcanza_priv_general"]  = df_maestro["Excedente_semestral"] >= matricula_privada_general
df_maestro["Alcanza_priv_medicina"] = df_maestro["Excedente_semestral"] >= matricula_privada_medicina
df_maestro["Alcanza_pub_fuera"]     = df_maestro["Excedente_semestral"] >= matricula_publica_fuera

cols_capa3 = ["Año", "Excedente", "Excedente_semestral",
              "Alcanza_priv_general", "Alcanza_priv_medicina", "Alcanza_pub_fuera"]
df_maestro[cols_capa3].round(0)
# Out:
#     Año  Excedente  Excedente_semestral  Alcanza_priv_general  \
# 0  2016   469222.0            2815332.0                 False
# 1  2017   514204.0            3085224.0                 False
# 2  2018   555159.0            3330954.0                 False
# 3  2019   600003.0            3600018.0                 False
# 4  2020   651577.0            3909462.0                 False
# 5  2021   663500.0            3981000.0                 False
# 6  2022   720308.0            4321848.0                 False
# 7  2023   865231.0            5191386.0                 False
# 8  2024  1001802.0            6010812.0                 False
# 9  2025  1141459.0            6848754.0                 False
#
#    Alcanza_priv_medicina  Alcanza_pub_fuera
# 0                  False               True
# 1                  False               True
# 2                  False               True
# 3                  False               True
# 4                  False               True
# 5                  False               True
# 6                  False               True
# 7                  False               True
# 8                  False               True
# 9                  False               True

# %%
# Déficit/superávit frente a cada referencia (último año)
fila_2025 = df_maestro[df_maestro["Año"] == 2025].iloc[0]
exc_sem_2025 = fila_2025 ["Excedente_semestral"]

print("=== AÑO 2025 ===")
print(f"Excedente mensual: ${fila_2025['Excedente']:,.0f}")
print(f"Excedente semestral (×6): ${exc_sem_2025:,.0f}")
print()
for nombre, costo in [
    ("Pública – Gratuidad",          matricula_publica_gratuita),
    ("Pública – Fuera de gratuidad", matricula_publica_fuera),
    ("Privada – General",            matricula_privada_general),
    ("Privada – Medicina",           matricula_privada_medicina),
]:
    diferencia = exc_sem_2025 - costo
    icono = "✅" if diferencia >= 0 else "🔴"
    print(f"{icono} {nombre}: ${costo:,.0f}  →  diferencia: ${diferencia:,.0f}")
# Out:
# === AÑO 2025 ===
# Excedente mensual: $1,141,459
# Excedente semestral (×6): $6,848,754
#
# ✅ Pública – Gratuidad: $0  →  diferencia: $6,848,754
# ✅ Pública – Fuera de gratuidad: $1,200,000  →  diferencia: $5,648,754
# 🔴 Privada – General: $8,500,000  →  diferencia: $-1,651,246
# 🔴 Privada – Medicina: $25,000,000  →  diferencia: $-18,151,246

# %% [markdown]
# ## Visualizaciones
#
# Tres gráficas, una por capa. Paleta sobria y profesional, adecuada para GitHub y portfolio.

# %%
# ── Configuración global de estilo ────────────────────────────────────────────
sns.set_theme(style="whitegrid", font_scale=1.1)
AZUL     = "#1A5276"
NARANJA  = "#CA6F1E"
VERDE    = "#1E8449"
ROJO     = "#922B21"
GRIS     = "#7F8C8D"

# ── Gráfica 1: Salario nominal vs salario real ────────────────────────────────

AZUL    = "#1A5276"
NARANJA = "#CA6F1E"

# Solo hasta 2025 — 2026 tiene IPC parcial (mayo), no comparable
df_graf1 = df_maestro[df_maestro["Año"] <= 2025].copy()
años = df_graf1["Año"].astype(int)

fig, ax = plt.subplots(figsize=(12, 5))

ax.plot(años, df_graf1["Salario_nominal"] / 1e3, color=NARANJA, marker="o", lw=2.2,
        label="Salario nominal (pesos corrientes)")
ax.plot(años, df_graf1["Salario_real"] / 1e3, color=AZUL, marker="s", lw=2.2, ls="--",
        label="Salario real (precios constantes)")

ax.set_title("Capa 1 — Salario nominal vs. salario real en Colombia (2016–2025)",
             fontsize=13, fontweight="bold", pad=14)
ax.set_xlabel("Año")
ax.set_ylabel("Miles de pesos COP")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"${x:,.0f}K"))
ax.set_xticks(años)
ax.legend(loc="upper left")
ax.grid(axis="y", alpha=0.4)

# Anotar primer y último punto
for col, color in [("Salario_nominal", NARANJA), ("Salario_real", AZUL)]:
    v_ini = df_graf1.loc[df_graf1["Año"] == 2016, col].values[0] / 1e3
    v_fin = df_graf1.loc[df_graf1["Año"] == 2025, col].values[0] / 1e3
    ax.annotate(f"${v_ini:,.0f}K", xy=(2016, v_ini), xytext=(4, 8),
                textcoords="offset points", fontsize=8.5, color=color, fontweight="bold")
    ax.annotate(f"${v_fin:,.0f}K", xy=(2025, v_fin), xytext=(-68, 8),
                textcoords="offset points", fontsize=8.5, color=color, fontweight="bold")

plt.tight_layout()
plt.savefig("datos_poder_adquisitivo/grafica_capa1_salario_real.png", dpi=150, bbox_inches="tight")
plt.show()
print("Guardada: datos_poder_adquisitivo/grafica_capa1_salario_real.png")
años = df_maestro["Año"].astype(int)
# Out:
# Guardada: datos_poder_adquisitivo/grafica_capa1_salario_real.png

# %%
# ── Gráfica 2: Excedente mensual ──────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(11, 5))

colores_barras = [VERDE if e > 0 else ROJO for e in df_maestro["Excedente"]]
bars = ax.bar(años, df_maestro["Excedente"] / 1e3, color=colores_barras,
              width=0.6, edgecolor="white", linewidth=0.8)

ax.axhline(0, color="black", linewidth=1.2)
ax.set_title("Capa 2 — Excedente mensual tras cubrir la línea de pobreza (2016–2025)",
             fontsize=13, fontweight="bold", pad=14)
ax.set_xlabel("Año")
ax.set_ylabel("Miles de pesos COP")
ax.set_xticks(años)
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"${x:,.0f}K"))
ax.grid(axis="y", alpha=0.4)

for bar, val in zip(bars, df_maestro["Excedente"] / 1e3):
    offset = 8 if val >= 0 else -18
    ax.text(bar.get_x() + bar.get_width() / 2, val + offset,
            f"${val:,.0f}K", ha="center", va="bottom", fontsize=7.5, fontweight="bold")

# Leyenda dinámica: solo muestra los colores que realmente aparecen en las barras
from matplotlib.patches import Patch
handles = []
if any(e > 0 for e in df_maestro["Excedente"]):
    handles.append(Patch(color=VERDE, label="Excedente positivo (sobre línea de pobreza)"))
if any(e <= 0 for e in df_maestro["Excedente"]):
    handles.append(Patch(color=ROJO, label="Déficit (bajo línea de pobreza)"))
ax.legend(handles=handles, loc="upper left")

plt.tight_layout()
plt.savefig("datos_poder_adquisitivo/grafica_capa2_excedente.png", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ── Gráfica 3: Excedente semestral vs costos de matrícula ────────────────────

AZUL    = "#1A5276"
GRIS    = "#7F8C8D"
NARANJA = "#CA6F1E"
ROJO    = "#922B21"

matricula_publica_fuera    = 1_200_000
matricula_privada_general  = 8_500_000
matricula_privada_medicina = 25_000_000

# Sin 2026 — IPC parcial
df_graf3 = df_maestro[df_maestro["Año"] <= 2025].copy()
años     = df_graf3["Año"].astype(int)
exc_sem  = df_graf3["Excedente_semestral"] / 1e6

fig, ax = plt.subplots(figsize=(13, 6))

# Área y línea del excedente
ax.fill_between(años, exc_sem, alpha=0.15, color=AZUL)
ax.plot(años, exc_sem, color=AZUL, marker="o", lw=2.2,
        label="Excedente semestral acumulable")

# Anotar cada punto
for a, v in zip(años, exc_sem):
    ax.annotate(f"${v:.1f}M", xy=(a, v),
                xytext=(0, 10), textcoords="offset points",
                ha="center", fontsize=7.5, color=AZUL, fontweight="bold")

# ── Etiqueta del excedente sobre la línea azul ────────────────────────────────
ax.text(2025.15, exc_sem.iloc[-1],
        "Excedente semestral\nacumulable",
        color=AZUL, fontsize=8, fontweight="bold",
        va="center", ha="left")

# Referencias horizontales con etiqueta SOBRE la línea
referencias = [
    ("Pública – Fuera de gratuidad",  matricula_publica_fuera,   GRIS,    "--"),
    ("Privada – Carrera general",      matricula_privada_general,  NARANJA, "-."),
    ("Privada – Medicina",             matricula_privada_medicina, ROJO,    ":"),
]
for nombre, costo, color, ls in referencias:
    y = costo / 1e6
    ax.axhline(y, color=color, ls=ls, lw=1.8)
    ax.text(2025.15, y, f"{nombre}\n(${costo/1e6:.1f}M)",
            color=color, fontsize=8, fontweight="bold",
            va="center", ha="left")

# Títulos y ejes
ax.set_title("Capa 3 — ¿Alcanza el excedente semestral para estudiar? (2016–2025)",
             fontsize=13, fontweight="bold", pad=14)
ax.set_xlabel("Año")
ax.set_ylabel("Precio de matrículas (COP)")

# Eje Y limpio
ax.set_ylim(0.5, 28)
ax.yaxis.set_major_locator(plt.MultipleLocator(2))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"${x:.0f}M"))

ax.set_xticks(años)
ax.grid(axis="y", alpha=0.3)

# ── Leyenda arriba ─────────────────────────────────────────────────────────────
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

leyenda_elementos = [
    Line2D([0], [0], color=AZUL,    lw=2, marker="o", label="Excedente semestral acumulable"),
    Line2D([0], [0], color=GRIS,    lw=1.8, ls="--",  label="Pública – Fuera de gratuidad ($1.2M)"),
    Line2D([0], [0], color=NARANJA, lw=1.8, ls="-.",  label="Privada – Carrera general ($8.5M)"),
    Line2D([0], [0], color=ROJO,    lw=1.8, ls=":",   label="Privada – Medicina ($25M)"),
]
ax.legend(handles=leyenda_elementos, loc="upper left", fontsize=8.5)

# Margen derecho para etiquetas sobre las líneas
plt.subplots_adjust(right=0.78)

plt.tight_layout()
plt.savefig("datos_poder_adquisitivo/grafica_capa3_matricula.png", dpi=150, bbox_inches="tight")
plt.show()
print("Guardada: datos_poder_adquisitivo/grafica_capa3_matricula.png")
# Out:
# Guardada: datos_poder_adquisitivo/grafica_capa3_matricula.png

# %% [markdown]
# ## Tabla Maestra Final
#
# Todos los indicadores calculados en una sola vista.

# %%
# ── Tabla Maestra Final ───────────────────────────────────────────────────────

cols_final = [
    "Año", "Salario_nominal", "Auxilio_transporte", "IPC", "Mes_IPC",
    "Salario_real", "Linea_pobreza", "Ingreso_total",
    "Excedente", "Excedente_semestral"
]

# Excluir 2026 — IPC parcial (solo hasta mayo), no comparable con años completos
df_final = df_maestro[cols_final].copy()
df_final = df_final[df_final["Año"] <= 2025].reset_index(drop=True)

# Renombrar columnas
display_cols = {
    "Año":                 "Año",
    "Salario_nominal":     "Salario nominal",
    "Auxilio_transporte":  "Auxilio transporte",
    "IPC":                 "IPC (último mes)",
    "Mes_IPC":             "Mes IPC",
    "Salario_real":        "Salario real (precios constantes)",
    "Linea_pobreza":       "Línea de pobreza",
    "Ingreso_total":       "Ingreso total",
    "Excedente":           "Excedente mensual",
    "Excedente_semestral": "Excedente semestral"
}
df_final_display = df_final.rename(columns=display_cols)

# Guardar CSV sin 2026
df_final.to_csv("datos_poder_adquisitivo/tabla_maestra.csv", index=False)
print("Tabla guardada (2016–2025) en datos_poder_adquisitivo/tabla_maestra.csv")
print()
print("Nota: 2026 se excluye de esta tabla porque el IPC disponible es parcial")
print("(dato hasta mayo 2026), lo que no permite una comparación rigurosa")
print("con los años anteriores que tienen el año completo cerrado.")
print()

df_final_display.style.format({
    "Salario nominal":                   "${:,.0f}",
    "Auxilio transporte":                "${:,.0f}",
    "IPC (último mes)":                  "{:.2f}",
    "Salario real (precios constantes)": "${:,.0f}",
    "Línea de pobreza":                  "${:,.0f}",
    "Ingreso total":                     "${:,.0f}",
    "Excedente mensual":                 "${:,.0f}",
    "Excedente semestral":               "${:,.0f}"
})
# Out:
# Tabla guardada (2016–2025) en datos_poder_adquisitivo/tabla_maestra.csv
#
# Nota: 2026 se excluye de esta tabla porque el IPC disponible es parcial
# (dato hasta mayo 2026), lo que no permite una comparación rigurosa
# con los años anteriores que tienen el año completo cerrado.
# <style type="text/css">
# </style>
# <table id="T_71082">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71082_level0_col0" class="col_heading level0 col0" >Año</th>
#       <th id="T_71082_level0_col1" class="col_heading level0 col1" >Salario nominal</th>
#       <th id="T_71082_level0_col2" class="col_heading level0 col2" >Auxilio transporte</th>
#       <th id="T_71082_level0_col3" class="col_heading level0 col3" >IPC (último mes)</th>
#       <th id="T_71082_level0_col4" class="col_heading level0 col4" >Mes IPC</th>
#       <th id="T_71082_level0_col5" class="col_heading level0 col5" >Salario real (precios constantes)</th>
#       <th id="T_71082_level0_col6" class="col_heading level0 col6" >Línea de pobreza</th>
#       <th id="T_71082_level0_col7" class="col_heading level0 col7" >Ingreso total</th>
#       <th id="T_71082_level0_col8" class="col_heading level0 col8" >Excedente mensual</th>
#       <th id="T_71082_level0_col9" class="col_heading level0 col9" >Excedente semestral</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71082_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71082_row0_col0" class="data row0 col0" >2016</td>
#       <td id="T_71082_row0_col1" class="data row0 col1" >$689,455</td>
#       <td id="T_71082_row0_col2" class="data row0 col2" >$77,700</td>
#       <td id="T_71082_row0_col3" class="data row0 col3" >93.11</td>
#       <td id="T_71082_row0_col4" class="data row0 col4" >Diciembre</td>
#       <td id="T_71082_row0_col5" class="data row0 col5" >$740,474</td>
#       <td id="T_71082_row0_col6" class="data row0 col6" >$297,933</td>
#       <td id="T_71082_row0_col7" class="data row0 col7" >$767,155</td>
#       <td id="T_71082_row0_col8" class="data row0 col8" >$469,222</td>
#       <td id="T_71082_row0_col9" class="data row0 col9" >$2,815,332</td>
#     </tr>
#     <tr>
#       <th id="T_71082_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_71082_row1_col0" class="data row1 col0" >2017</td>
#       <td id="T_71082_row1_col1" class="data row1 col1" >$737,717</td>
#       <td id="T_71082_row1_col2" class="data row1 col2" >$83,140</td>
#       <td id="T_71082_row1_col3" class="data row1 col3" >96.92</td>
#       <td id="T_71082_row1_col4" class="data row1 col4" >Diciembre</td>
#       <td id="T_71082_row1_col5" class="data row1 col5" >$761,161</td>
#       <td id="T_71082_row1_col6" class="data row1 col6" >$306,653</td>
#       <td id="T_71082_row1_col7" class="data row1 col7" >$820,857</td>
#       <td id="T_71082_row1_col8" class="data row1 col8" >$514,204</td>
#       <td id="T_71082_row1_col9" class="data row1 col9" >$3,085,224</td>
#     </tr>
#     <tr>
#       <th id="T_71082_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_71082_row2_col0" class="data row2 col0" >2018</td>
#       <td id="T_71082_row2_col1" class="data row2 col1" >$781,242</td>
#       <td id="T_71082_row2_col2" class="data row2 col2" >$88,211</td>
#       <td id="T_71082_row2_col3" class="data row2 col3" >100.00</td>
#       <td id="T_71082_row2_col4" class="data row2 col4" >Diciembre</td>
#       <td id="T_71082_row2_col5" class="data row2 col5" >$781,242</td>
#       <td id="T_71082_row2_col6" class="data row2 col6" >$314,294</td>
#       <td id="T_71082_row2_col7" class="data row2 col7" >$869,453</td>
#       <td id="T_71082_row2_col8" class="data row2 col8" >$555,159</td>
#       <td id="T_71082_row2_col9" class="data row2 col9" >$3,330,954</td>
#     </tr>
#     <tr>
#       <th id="T_71082_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_71082_row3_col0" class="data row3 col0" >2019</td>
#       <td id="T_71082_row3_col1" class="data row3 col1" >$828,116</td>
#       <td id="T_71082_row3_col2" class="data row3 col2" >$97,032</td>
#       <td id="T_71082_row3_col3" class="data row3 col3" >103.80</td>
#       <td id="T_71082_row3_col4" class="data row3 col4" >Diciembre</td>
#       <td id="T_71082_row3_col5" class="data row3 col5" >$797,800</td>
#       <td id="T_71082_row3_col6" class="data row3 col6" >$325,145</td>
#       <td id="T_71082_row3_col7" class="data row3 col7" >$925,148</td>
#       <td id="T_71082_row3_col8" class="data row3 col8" >$600,003</td>
#       <td id="T_71082_row3_col9" class="data row3 col9" >$3,600,018</td>
#     </tr>
#     <tr>
#       <th id="T_71082_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_71082_row4_col0" class="data row4 col0" >2020</td>
#       <td id="T_71082_row4_col1" class="data row4 col1" >$877,803</td>
#       <td id="T_71082_row4_col2" class="data row4 col2" >$102,854</td>
#       <td id="T_71082_row4_col3" class="data row4 col3" >105.48</td>
#       <td id="T_71082_row4_col4" class="data row4 col4" >Diciembre</td>
#       <td id="T_71082_row4_col5" class="data row4 col5" >$832,199</td>
#       <td id="T_71082_row4_col6" class="data row4 col6" >$329,080</td>
#       <td id="T_71082_row4_col7" class="data row4 col7" >$980,657</td>
#       <td id="T_71082_row4_col8" class="data row4 col8" >$651,577</td>
#       <td id="T_71082_row4_col9" class="data row4 col9" >$3,909,462</td>
#     </tr>
#     <tr>
#       <th id="T_71082_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_71082_row5_col0" class="data row5 col0" >2021</td>
#       <td id="T_71082_row5_col1" class="data row5 col1" >$908,526</td>
#       <td id="T_71082_row5_col2" class="data row5 col2" >$106,454</td>
#       <td id="T_71082_row5_col3" class="data row5 col3" >111.41</td>
#       <td id="T_71082_row5_col4" class="data row5 col4" >Diciembre</td>
#       <td id="T_71082_row5_col5" class="data row5 col5" >$815,480</td>
#       <td id="T_71082_row5_col6" class="data row5 col6" >$351,480</td>
#       <td id="T_71082_row5_col7" class="data row5 col7" >$1,014,980</td>
#       <td id="T_71082_row5_col8" class="data row5 col8" >$663,500</td>
#       <td id="T_71082_row5_col9" class="data row5 col9" >$3,981,000</td>
#     </tr>
#     <tr>
#       <th id="T_71082_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_71082_row6_col0" class="data row6 col0" >2022</td>
#       <td id="T_71082_row6_col1" class="data row6 col1" >$1,000,000</td>
#       <td id="T_71082_row6_col2" class="data row6 col2" >$117,172</td>
#       <td id="T_71082_row6_col3" class="data row6 col3" >126.03</td>
#       <td id="T_71082_row6_col4" class="data row6 col4" >Diciembre</td>
#       <td id="T_71082_row6_col5" class="data row6 col5" >$793,462</td>
#       <td id="T_71082_row6_col6" class="data row6 col6" >$396,864</td>
#       <td id="T_71082_row6_col7" class="data row6 col7" >$1,117,172</td>
#       <td id="T_71082_row6_col8" class="data row6 col8" >$720,308</td>
#       <td id="T_71082_row6_col9" class="data row6 col9" >$4,321,848</td>
#     </tr>
#     <tr>
#       <th id="T_71082_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_71082_row7_col0" class="data row7 col0" >2023</td>
#       <td id="T_71082_row7_col1" class="data row7 col1" >$1,160,000</td>
#       <td id="T_71082_row7_col2" class="data row7 col2" >$140,606</td>
#       <td id="T_71082_row7_col3" class="data row7 col3" >137.72</td>
#       <td id="T_71082_row7_col4" class="data row7 col4" >Diciembre</td>
#       <td id="T_71082_row7_col5" class="data row7 col5" >$842,289</td>
#       <td id="T_71082_row7_col6" class="data row7 col6" >$435,375</td>
#       <td id="T_71082_row7_col7" class="data row7 col7" >$1,300,606</td>
#       <td id="T_71082_row7_col8" class="data row7 col8" >$865,231</td>
#       <td id="T_71082_row7_col9" class="data row7 col9" >$5,191,386</td>
#     </tr>
#     <tr>
#       <th id="T_71082_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_71082_row8_col0" class="data row8 col0" >2024</td>
#       <td id="T_71082_row8_col1" class="data row8 col1" >$1,300,000</td>
#       <td id="T_71082_row8_col2" class="data row8 col2" >$162,000</td>
#       <td id="T_71082_row8_col3" class="data row8 col3" >144.88</td>
#       <td id="T_71082_row8_col4" class="data row8 col4" >Diciembre</td>
#       <td id="T_71082_row8_col5" class="data row8 col5" >$897,294</td>
#       <td id="T_71082_row8_col6" cla

# %% [markdown]
# ##### Conclusiones
#
# ### ¿El salario mínimo en Colombia ha mejorado el poder adquisitivo entre 2016 y 2025?
#
# **Capa 1 — Salario real:**
# El salario nominal creció sustancialmente en la última década, pasando de $689.455 en 2016 a $1.423.500 en 2025 — un aumento de aproximadamente 106% en pesos corrientes. Sin embargo, cuando se descuenta la inflación, el salario real muestra un crecimiento significativamente más modesto. El período 2021-2023 fue especialmente duro: la inflación superó ampliamente los aumentos nominales, erosionando el poder de compra. Los años 2024-2025 muestran una recuperación parcial, impulsada por aumentos del salario mínimo decretados por encima de la inflación.
#
# **Capa 2 — ¿Vivir o sobrevivir?**
# El ingreso total (salario + auxilio de transporte) se ha mantenido por encima de la línea de pobreza en la mayor parte del período, pero el excedente es pequeño y vulnerable. En los años de alta inflación (2022-2023), el margen se redujo considerablemente. Una persona que vive del salario mínimo está técnicamente sobre la línea de pobreza monetaria, pero con un colchón estrecho que no tolera imprevistos.
#
# **Capa 3 — ¿Invertir en el futuro?**
# El excedente semestral no alcanza, en ningún año del período, para pagar una matrícula en universidad privada (ni siquiera en las más económicas). La universidad pública con política de gratuidad es, en la práctica, la **única vía realista** para que alguien que depende del salario mínimo pueda acceder a educación superior sin endeudarse. Esto no es una observación moral — es el resultado directo de los números: la brecha entre el excedente acumulable y el costo de matrícula privada es estructural y se mantiene en todo el período analizado.
#
# **Respuesta a la pregunta central:**
# El salario mínimo en Colombia *sí ha mejorado* en términos nominales, pero el avance en poder adquisitivo real es frágil y desigual a lo largo del tiempo. El colombiano promedio que gana el mínimo no está mejorando su posición económica al ritmo que los titulares de cada enero sugieren. Está sobreviviendo con un margen estrecho, y la posibilidad de invertir en educación superior privada permanece fuera de alcance durante todo el período 2016-2025.
#
# ---
# *Fuentes: DANE (IPC, Líneas de pobreza), Banrep / Ministerio del Trabajo (SMMLV y Auxilio de transporte), datos de matrículas universitarias Colombia 2024.*
# *Elaborado por: Mauxy Salcedo — Proyecto de portafolio, 2026.*
