# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.makedirs("datos_poder_adquisitivo", exist_ok=True)

# %%
ruta = "datos_poder_adquisitivo/anex-IPC-indices-may2026 (1).xlsx"

# %%
df = pd.read_excel(ruta, header=7)

# %%
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0        Mes     2003.00     2004.00     2005.00     2006.00     2007.00
# 1      Enero       50.42       53.54       56.45       59.02       61.80
# 2    Febrero       50.98       54.18       57.02       59.41       62.53
# 3      Marzo       51.51       54.71       57.46       59.83       63.29
# 4      Abril       52.10       54.96       57.72       60.09       63.85
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 15  \
# 0     2008.00     2009.00     2010.00     2011.00  ...      2017.00
# 1       65.51       70.21       71.69       74.12  ...        94.07
# 2       66.50       70.80       72.28       74.57  ...        95.01
# 3       67.04       71.15       72.46       74.77  ...        95.46
# 4       67.51       71.38       72.79       74.86  ...        95.91
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0      2018.00      2019.00      2020.00      2021.00      2022.00
# 1        97.53       100.60       104.24       105.91       113.26
# 2        98.22       101.18       104.94       106.58       115.11
# 3        98.45       101.62       105.53       107.12       116.26
# 4        98.91       102.12       105.70       107.76       117.71
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Base Diciembre de 2018 = 100,00
# 0      2023.00      2024.00      2025.00                          2026.00
# 1       128.27       138.98       146.24                           154.07
# 2       130.40       140.49       147.90                           155.73
# 3       131.77       141.48       148.68                           156.94
# 4       132.80       142.32       149.66                           158.17
#
# [5 rows x 25 columns]

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Base Diciembre de 2018 = 100,00'],
#       dtype='str')
